# %% [markdown]
# #  Introduction
# ##### For BAN110 - Project- Census Income Dataset-Adult (From UCI-Machine Learning Repository.)
#
# ##### Task - Data pre-processing.
#
# ##### Group Members:
#       1.Shreyas Shah
#       2.Leslie Stefany Lopez
#       3.Farzaneh Soori
#       4.Akash Binilmon Philips
#
# ##### Abstract - Predict whether income exceeds $50K/yr based on census data. Also known as "Census Income" dataset.
#     Source:
#     Donor : Ronny Kohavi and Barry Becker, Data Mining and Visualization, Silicon Graphics.
#     e-mail: ronnyk '@' live.com for questions.
#     Data Set Information:
#     Extraction was done by Barry Becker from the 1994 Census database. A set of reasonably clean records was extracted using the
#     following conditions: ((AAGE>16) && (AGI>100) && (AFNLWGT>1)&& (HRSWK>0))
#
#     Prediction task is to determine whether a person makes over 50K a year.

# %% [markdown]
# ![](adultdataset.JPG)

# %% [markdown]
# ![](C:/Users/shrey/Desktop/SHREYAS%20SHAH/BAN%20Seneca%20college/SASUniversityEdition/myfolders/APROJECT/adultdataset.JPG)

# %% [markdown]
# While gathering data, one might come across three main factors that would contribute to the quality of data:
# #### 1.	Accuracy:
# Erroneous values that deviate from the expected. The causes for inaccurate data can be various, which include:
# •	Human/computer errors during data entry and transmission
# •	Users deliberately submitting incorrect values (called disguised missing data)
# •	Incorrect formats for input fields
# •	Duplication of training examples
# #### 2.	Completeness:
# Lacking attribute/feature values or values of interest. The dataset might be incomplete due to:
# •	Unavailability of data
# •	Deletion of inconsistent data
# •	Deletion of data deemed irrelevant initially
# #### 3.	Consistency:
# Aggregation of data is inconsistent.

# %% [markdown]
# ##### To achieve the Accuracy, Completeness and Consistency, We may need to perform Data Cleaning, Data Integration, Data Reduction and Data Transformation.
#     In our dataset we will do the following,
#     1. Descriptive Statistics.- Dataset Description.
#     2. Missing values finding. - Data Cleaning (missing values), Errors finding - Data Cleaning.
#        a. Character Variables
#        b. Numeric Variables
#     3. Missing values treating.- Data Reduction/Data Transformation, Errors treating- Data Reduction/Data Transformation.
#        a. Character Variables
#        b. Numeric Variables
#     4. Outliers finding.- Data Cleaning (Outliers)
#        a. Character Variables
#        b. Numeric Variables
#     5. Outliers treating.- Data Reduction/Data Transformation.
#        a. Character Variables
#        b. Numeric Variables
#     6. Duplicate observations finding.- Data cleaning.
#     7. Duplicate observatings removing.= Data reduction.
#     8. Convert Annual_Income Variable in to 0 and 1. (0 for <=50K and 1 for >50K)
#     As we have all the details of the all 14 variables and 15th Targeted Variable in one table at one place,
#     we do not required Data Integration from two or more different tables.
#
# ### After above PRE-PROCESSING our dataset will be ready for predictive analysis.

# %% [markdown]
# ### Some details about Data Cleaning, Data Integration, Data Reduction and Data Transformation.
# #### Data cleaning
# Data cleaning refers to techniques to ‘clean’ data by removing outliers, replacing missing values, smoothing noisy data, and correcting inconsistent data. Many techniques are used to perform each of these tasks, where each technique is specific to user’s preference or problem set. Below, each task is explained in terms of the techniques used to overcome it.
# ##### Missing values
# In order to deal with missing data, multiple approaches can be used.
# 1.	Removing the training example: You can ignore the training example if the output label is missing (if it is a classification problem). This is usually discouraged as it leads to loss of data, as you are removing the attribute values that can add value to data set as well.
# 2.	Filling in missing value manually: This approach is time consuming, and not recommended for huge data sets.
# 3.	Using a standard value to replace the missing value: The missing value can be replaced by a global constant such as ‘N/A’ or ‘Unknown’. This is a simple approach, but not foolproof.
# 4.	Using central tendency (mean, median, mode) for attribute to replace the missing value: Based on data distribution, mean (in case of normal distribution) or median (for non-normal distribution) can be used to fill in for the missing value.
# 5.	Using central tendency (mean, median, mode) for attribute belonging to same class to replace the missing value: This is the same as method 4, except that the measures of central tendency are specific to each class.
# 6.	Using the most probable value to fill in the missing value: Using algorithms like regression and decision tree, the missing values can be predicted and replaced.
# ##### Noisy data
# Noise is defined as a random variance in a measured variable. For numeric values, boxplots and scatter plots can be used to identify outliers. To deal with these anomalous values, data smoothing techniques are applied, which are described below.
# 1.	Binning: Using binning methods smooths sorted value by using the values around it. The sorted values are then divided into ‘bins’. There are various approaches to binning. Two of them are smoothing by bin means where each bin is replaced by the mean of bin’s values, and smoothing by bin medians where each bin is replaced by the median of bin’s values.
# 2.	Regression: Linear regression and multiple linear regression can be used to smooth the data, where the values are conformed to a function.
# 3.	Outlier analysis: Approaches such as clustering can be used to detect outliers and deal with them.
# 4.	Clustering
#
# #### Data integration
# Since data is being collected from multiple sources, data integration has become a vital part of the process. This may lead to redundant and inconsistent data, which could result in poor accuracy and speed of data model. To deal with these issues and maintain the data integrity, approaches such as tuple duplication detection and data conflict detection are sought after. The most common approaches to integrate data are explained below.
# 1.	Data consolidation: The data is physically bought together to one data store. This usually involves Data Warehousing.
# 2.	Data propagation: Copying data from one location to another using applications is called data propagation. It can be synchronous or asynchronous and is event-driven.
# 3.	Data virtualization: An interface is used to provide a real-time and unified view of data from multiple sources. The data can be viewed from a single point of access.
#
# #### Data reduction
# The purpose of data reduction is to have a condensed representation of the data set which is smaller in volume, while maintaining the integrity of original. This results in efficient yet similar results. A few methods to reduce the volume of data are:
# 1.	Missing values ratio: Attributes that have more missing values than a threshold are removed.
# 2.	Low variance filter: Normalized attributes that have variance (distribution) less than a threshold are also removed, since little changes in data means less information.
# 3.	High correlation filter: Normalized attributes that have correlation coefficient more than a threshold are also removed, since similar trends means similar information is carried. Correlation coefficient is usually calculates using statistical methods such as Pearson’s chi-square value etc.
# 4.	Principal component analysis: Principal component analysis, or PCA, is a statistical method which reduces the numbers of attributes by lumping highly correlated attributes together. With each iteration, the initial features are reduced to principal components, with greater variance than the original set on the condition that they are uncorrelated with the preceding components. This method, however, only works for features with numerical values.
#
# #### Data transformation
# The final step of data preprocessing is transforming the data into form appropriate for Data Modeling. Strategies that enable data transformation include:
# 1.	Smoothing
# 2.	Attribute/feature construction: New attributes are constructed from the given set of attributes.
# 3.	Aggregation: Summary and Aggregation operations are applied on the given set of attributes to come up with new attributes.
# 4.	Normalization: The data in each attribute is scaled between a smaller range e.g. 0 to 1 or -1 to 1.
# 5.	Discretization: Raw values of the numeric attributes are replaced by discrete or conceptual intervals, which can in return be further organized into higher level intervals.
# 6.	Concept hierarchy generation for nominal data: Values for nominal data are generalized to higher order concepts.

# %% [markdown]
# # STEP - 01 : Descriptive Statistics

# %% [markdown]
# ##### Download adult.data, adult.test  and adult.names files from th UCI platform.
# ##### Open adult.data and adult.test  as xlsx files and adult.names as text file.
# ##### Save adult.data and adult.test as csv files in SASUniversityEdition/myfolders/APROJECT.
# ##### Follow the steps from LIBNAME  Onwards as under.

# %%
LIBNAME AFLS'/folders/myfolders/APROJECT';
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
#
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# td.linenos { background-color: #f0f0f0; padding-right: 10px; }
# span.lineno { background-color: #f0f0f0; padding: 0 5px 0 5px; }
# pre { line-height: 125%; }
# body .hll { background-color: #ffffcc }
# body  { background: #ffffff; }
# body .c { color: #0000FF } /* Comment */
# body .k { color: #ff0000; font-weight: bold } /* Keyword */
# body .n { color: #008000 } /* Name */
# body .ch { color: #0000FF } /* Comment.Hashbang */
# body .cm { color: #0000FF } /* Comment.Multiline */
# body .cp { color: #0000FF } /* Comment.Preproc */
# body .cpf { color: #0000FF } /* Comment.PreprocFile */
# body .c1 { color: #0000FF } /* Comment.Single */
# body .cs { color: #0000FF } /* Comment.Special */
# ...

# %% [markdown]
# ### Importing file adulttrain.csv to create dataset AFLS.ATRAIN

# %%
PROC IMPORT DATAFILE='/folders/myfolders/APROJECT/adulttrain.csv'
   DBMS=CSV
   OUT=AFLS.ATRAIN
   REPLACE
   ;
   GETNAMES = NO;
RUN;
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
#
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# td.linenos { background-color: #f0f0f0; padding-right: 10px; }
# span.lineno { background-color: #f0f0f0; padding: 0 5px 0 5px; }
# pre { line-height: 125%; }
# body .hll { background-color: #ffffcc }
# body  { background: #ffffff; }
# body .c { color: #0000FF } /* Comment */
# body .k { color: #ff0000; font-weight: bold } /* Keyword */
# body .n { color: #008000 } /* Name */
# body .ch { color: #0000FF } /* Comment.Hashbang */
# body .cm { color: #0000FF } /* Comment.Multiline */
# body .cp { color: #0000FF } /* Comment.Preproc */
# body .cpf { color: #0000FF } /* Comment.PreprocFile */
# body .c1 { color: #0000FF } /* Comment.Single */
# body .cs { color: #0000FF } /* Comment.Special */
# ...

# %% [markdown]
# #### In SAS generated table we can see that VAR8  and  VAR14 lengths are not enough to accomodate the longest character values, so we are redifining the length for VAR8 and  VAR14 from 13 to 14 and 13 to 26 respectively.

# %%
DATA AFLS.ATRAIN    ;
   %let _EFIERR_ = 0; /* set the ERROR detection macro variable */
   INFILE '/folders/myfolders/APROJECT/adulttrain.csv' delimiter = ',' MISSOVER DSD lrecl=32767 ;
   FORMAT 
        VAR1 best12.
        VAR2 $16.
        VAR3 best12.
        VAR4 $12.
        VAR5 best12.
        VAR6 $21.
        VAR7 $17.
        VAR8 $14.
        VAR9 $18.
        VAR10 $6.
        VAR11 best12.
        VAR12 best12.
        VAR13 best12.
        VAR14 $26.
        VAR15 $5.
        ;
   INPUT
       VAR1 
       VAR2  $
       VAR3
       VAR4  $
       VAR5
       VAR6  $
       VAR7  $
       VAR8  $
       VAR9  $
       VAR10 $
       VAR11
       VAR12
       VAR13
       VAR14 $
       VAR15 $
       ;
   IF _ERROR_ THEN CALL SYMPUTX('_EFIERR_',1);  /* set ERROR detection macro variable */
RUN;

   TITLE "AFLS.ATRAIN DATASTE FIRST 10 OBSERVATIONS";
PROC PRINT DATA=AFLS.ATRAIN (OBS=10);
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
   TITLE "DESCRIPTION OF VARIABLES FOR AFLS.ATRAIN DATASET";
PROC CONTENTS DATA=AFLS.ATRAIN;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# ### Assigning names to the variables as per the Dataset Description.

# %%
DATA AFLS.ADULTTRAIN;
   RENAME
     VAR1=age 
     VAR2=workclass
     VAR3=fnlwgt
     VAR4=education
     VAR5=education_num
     VAR6=marital_status
     VAR7=occupation
     VAR8=relationship
     VAR9=race
     VAR10=sex
     VAR11=capital_gain
     VAR12=capital_loss
     VAR13=hours_per_week
     VAR14=native_country
     VAR15=Annual_incomegt50k
     ;
   SET AFLS.ATRAIN;
RUN;        

   TITLE "FIRST 10 OBSERVATIONS OF AFLS.ADULTTRAIN DATA SET";
PROC PRINT DATA=AFLS.ADULTTRAIN (OBS=10);
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
   TITLE "VARIABLE DESCRIPTION FOR AFLS.ADULTTRAIN DATA SET";
PROC CONTENTS DATA=AFLS.ADULTTRAIN VARNUM;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# # Descriptive Statistics:For AFLS.ADULTTRAIN

# %% [markdown]
# #### Let's add Description in the details of variable for batter understanding of the datasets.

# %% [markdown]
# ![](descriptivestatistics.jpg)

# %% [markdown]
# ![](C:/Users/shrey/Desktop/SHREYAS%20SHAH/BAN%20Seneca%20college/SASUniversityEdition/myfolders/APROJECT/descriptivestatistics.JPG)

# %% [markdown]
# ##### Before starting  to find Missing values, Errors and Outliers first of all we need to generate unique id in both Train and Test datasets for each observation in order to exactly point out which observation is containing missing value, error or outlier in character or numeric variables and then we can either treat them or remove them from the dataset in order to get clean dataset for Predctive Analysis.

# %%
DATA AFLS.ATRAIN;
   SET AFLS.ADULTTRAIN;
   adult_id = _N_;
RUN;

 TITLE "Random 10 observations showing missing value and new variable adult_id";
PROC PRINT DATA=AFLS.ATRAIN(FIRSTOBS=1561 OBS=1570) NOOBS;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
   TITLE "VARIABLE DESCRIPTION FOR AFLS.ATRAIN DATA SET";
PROC CONTENTS DATA=AFLS.ATRAIN VARNUM;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# ## We can see that in the DATASET AFLS.ATRAIN we have added 16th Variable UNIQUE ID - adult_id.

# %% [markdown]
# # STEP - 02 : Missing Value Finding and Errors Finding.
# ###    a. Character Variables.

# %% [markdown]
# ##### From dataset description in adult.names file we understood that missing values or unknowns in Character Variables ars shown by "?"
# in this Adult Census Income Dataset. So, let's find missing values and Errors in both Train and Test Datasets.

# %% [markdown]
# ### First, checking character variables for the dataset AFLS.ATRAIN

# %%
   TITLE "Checking Missing Values and Errors of workclass";
PROC FORMAT; 
   VALUE $workclass_check 'Private', 'Self-emp-not-inc', 'Self-emp-inc','Federal-gov', 
   'Local-gov', 'State-gov', 'Without-pay', 'Never-worked'= 'valid'
                       '?'   = ' missing'
                       other = 'Error'; 
RUN; 

PROC FREQ DATA=AFLS.ATRAIN; 
   TABLES workclass / NOCUM NOPERCENT MISSING ; 
   FORMAT workclass $workclass_check.; 
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# ##### We can see that there are no Errors and 1836 Missing values in the Variable 'workclass' in dataset AFLS.ATRAIN.

# %%
   TITLE "Checking Missing Values and Errors of education";
PROC FORMAT; 
   VALUE $education_check 'Bachelors', 'Some-college', '11th', 'HS-grad', 'Prof-school', 'Assoc-acdm', 
   'Assoc-voc', '9th', '7th-8th', '12th', 'Masters', '1st-4th', '10th', 'Doctorate', '5th-6th', 'Preschool'= 'valid'
                       '?'   = ' missing'
                       other = 'Error'; 
RUN; 

PROC FREQ DATA=AFLS.ATRAIN; 
   TABLES education / NOCUM NOPERCENT MISSING ; 
   FORMAT education $education_check.; 
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# ##### We can see that there are no Errors and no Missing values in the Variable 'education' in dataset AFLS.ATRAIN.

# %%
   TITLE "Checking Missing Values and Errors of marital_status";
PROC FORMAT; 
   VALUE $marital_status_check 'Married-civ-spouse', 'Divorced', 'Never-married', 'Separated', 'Widowed', 
   'Married-spouse-absent', 'Married-AF-spouse'= 'valid'
                       '?'   = ' missing'
                       other = 'Error'; 
RUN; 

PROC FREQ DATA=AFLS.ATRAIN; 
   TABLES marital_status / NOCUM NOPERCENT MISSING ; 
   FORMAT marital_status $marital_status_check.; 
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# ##### We can see that there are no Errors and no Missing values in the Variable 'marital_status' in dataset AFLS.ATRAIN.

# %%
   TITLE "Checking Missing Values and Errors of occupation";
PROC FORMAT; 
   VALUE $occupation_check 'Tech-support', 'Craft-repair', 'Other-service', 'Sales', 'Exec-managerial', 
   'Prof-specialty', 'Handlers-cleaners', 'Machine-op-inspct', 'Adm-clerical', 'Farming-fishing', 
   'Transport-moving', 'Priv-house-serv', 'Protective-serv', 'Armed-Forces'= 'valid'
                       '?'   = ' missing'
                       other = 'Error'; 
RUN; 

PROC FREQ DATA=AFLS.ATRAIN; 
   TABLES occupation / NOCUM NOPERCENT MISSING ; 
   FORMAT occupation $occupation_check.; 
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# ##### We can see that there are no Errors and 1843 Missing values in the Variable 'occupation' in dataset AFLS.ATRAIN.

# %%
   TITLE "Checking Missing Values and Errors of relationship";
PROC FORMAT; 
   VALUE $relationship_check 'Wife', 'Own-child', 'Husband', 'Not-in-family', 'Other-relative', 'Unmarried'= 'valid'
                       '?'   = ' missing'
                       other = 'Error'; 
RUN; 

PROC FREQ DATA=AFLS.ATRAIN; 
   TABLES relationship / NOCUM NOPERCENT MISSING ; 
   FORMAT relationship $relationship_check.; 
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# ##### We can see that there are no Errors and no Missing values in the Variable 'relationship' in dataset AFLS.ATRAIN.

# %%
   TITLE "Checking Missing Values and Errors of race";
PROC FORMAT; 
   VALUE $race_check 'White', 'Asian-Pac-Islander', 'Amer-Indian-Eskimo', 'Other', 'Black'= 'valid'
                       '?'   = ' missing'
                       other = 'Error'; 
RUN; 

PROC FREQ DATA=AFLS.ATRAIN; 
   TABLES race / NOCUM NOPERCENT MISSING ; 
   FORMAT race $race_check.; 
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# ##### We can see that there are no Errors and no Missing values in the Variable 'race' in dataset AFLS.ATRAIN.

# %%
   TITLE "Checking Missing Values and Errors of sex";
PROC FORMAT; 
   VALUE $sex_check 'Female', 'Male'= 'valid'
                       '?'   = ' missing'
                       other = 'Error'; 
RUN; 

PROC FREQ DATA=AFLS.ATRAIN; 
   TABLES sex / NOCUM NOPERCENT MISSING ; 
   FORMAT sex $sex_check.; 
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# ##### We can see that there are no Errors and no Missing values in the Variable 'sex' in dataset AFLS.ATRAIN.

# %%
   TITLE "Checking Missing Values and Errors of native_country";
PROC FORMAT; 
   VALUE $native_country_check 'United-States', 'Cambodia', 'England', 'Puerto-Rico', 'Canada', 
   'Germany', 'Outlying-US(Guam-USVI-etc)', 'India', 'Japan', 'Greece', 'South', 'China', 'Cuba', 
   'Iran', 'Honduras', 'Philippines', 'Italy', 'Poland', 'Jamaica', 'Vietnam', 'Mexico', 'Portugal', 
   'Ireland', 'France', 'Dominican-Republic', 'Laos', 'Ecuador', 'Taiwan', 'Haiti', 'Columbia', 'Hungary', 
   'Guatemala', 'Nicaragua', 'Scotland', 'Thailand', 'Yugoslavia', 'El-Salvador', 'Trinadad&Tobago', 
   'Peru', 'Hong', 'Holand-Netherlands'= 'valid'
                       '?'   = ' missing'
                       other = 'Error'; 
RUN; 

PROC FREQ DATA=AFLS.ATRAIN; 
   TABLES native_country / NOCUM NOPERCENT MISSING ; 
   FORMAT native_country $native_country_check.; 
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# ##### We can see that there are no Errors and 583 Missing values in the Variable 'native_country' in dataset AFLS.ATRAIN.

# %%
   TITLE "Checking Missing Values and Errors of annual_incomegt50k";
PROC FORMAT; 
   VALUE $annual_incomegt50k_check '<=50K', '>50K'= 'valid'
                       '?'   = ' missing'
                       other = 'Error'; 
RUN; 

PROC FREQ DATA=AFLS.ATRAIN; 
   TABLES annual_incomegt50k / NOCUM NOPERCENT MISSING ; 
   FORMAT annual_incomegt50k $annual_incomegt50k_check.; 
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# ##### We can see that there are no Errors and no Missing values in the Variable 'annual_incomegt50k' in dataset AFLS.ATRAIN.

# %% [markdown]
# ###    b. Numeric Variables.

# %% [markdown]
# ### First, checking numeric variables for the dataset AFLS.ATRAIN for missing values and Errors

# %%
   TITLE "STATISTICS FOR AFLS.ATRAIN DATA SET";
PROC MEANS DATA=AFLS.ATRAIN N NMISS MEAN MEDIAN MIN MAX ;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# ##### Above table shows that there are no SAS missing values in any of the numeric variables in the AFLS.ATRAIN data set.
#
# But, sometimes 99,999,9999, 99999 or 999999 used in place of missing values.

# %% [markdown]
# ##### Let's check all numeric variables for Missing values. (Based on 99,999,9999,99999,999999)

# %%
DATA AFLS.missingninetrain;
   SET AFLS.ATRAIN (DROP = adult_id);
   ARRAY Nums[*] _numeric_;
   DO iii = 1 TO DIM (Nums);
   IF Nums[iii] = 99 THEN Nums[iii] = .;
   ELSE IF Nums[iii] = 999 THEN Nums[iii] = .;
   ELSE IF Nums[iii] = 9999 THEN Nums[iii] = .;
   ELSE IF Nums[iii] = 99999 THEN Nums[iii] =.;
   ELSE IF Nums[iii] = 999999 THEN Nums[iii] = .;
   END
   ;
   DROP iii;
RUN;

   TITLE"Checking Missing Values from the AFLS.ATRAIN  and calculating Mean and Median";
PROC MEANS DATA =AFLS.missingninetrain n nmiss Mean Std Median ;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# ### We can see that missing values are only in capital_gain = 159 and hours_per_week = 85.
# ### Now let's find Errors if any in the numeric variables.

# %%
   TITLE "Listing of Errors  in AFLS.ATRAIN DATA SET";
DATA _null_;
   SET AFLS.ATRAIN;
   FILE PRINT;
   SET AFLS.ATRAIN (KEEP = age fnlwgt education_num capital_gain capital_loss hours_per_week adult_id);
   X = INPUT(age,8.);
   IF _ERROR_ THEN DO;
   PUT "Invalid value " age "for age in adult_id= " adult_id;
      _ERROR_ = 0;
   END;
   X = INPUT(fnlwgt,8.);
   IF _ERROR_ THEN DO;
      PUT "Invalid value " fnlwgt "for fnlwgr in adult_id= " adult_id;
      _ERROR_ = 0;
   END;
   X = INPUT(education_num,8.);
   IF _ERROR_ THEN DO;
      PUT "Invalid value " education_num "for education_num in adult_id= " adult_id;
      _ERROR_ = 0;
   END;
   X= INPUT(capital_gain,8.);
   IF _ERROR_ THEN DO;
      PUT "Invalid value " capital_gain "for capital_gain in adult_id= " adult_id;
      _ERROR_ = 0;
   END;
   X = INPUT(capital_loss,8.);
   IF _ERROR_ THEN DO;
      PUT "Invalid value " capital_loss "for capital_loss in adult_id= " adult_id;
      _ERROR_ = 0;
   END;
   X = INPUT(hours_per_week,8.);
   IF _ERROR_ THEN DO;
      PUT "Invalid value " hours_per_week "for hours_per_week in adult_id= " adult_id;
      _ERROR_ = 0;
   END;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# ### We can see that there is no output for the errors in numeric variables, so we can confirm that there are no Errors in the numeric variables in the AFLS.ATRAIN Dataset.

# %% [markdown]
# ![](step2summary.JPG)

# %% [markdown]
# ![](C:/Users/shrey/Desktop/SHREYAS%20SHAH/BAN%20Seneca%20college/SASUniversityEdition/myfolders/APROJECT/step2summary.JPG)

# %% [markdown]
# # STEP - 03 : Missing Value Treating and Errors Treating.
# ###    a. Character Variables.

# %% [markdown]
# ##### We havew missing values in three character variables workclass, occupation and native_country in AFLS.ATRAIN & AFLS.ATEST. let's remove observations containing missing values in all the three variables.

# %% [markdown]
# ## Let's create AFLS.ADTRAIN from AFLS.ATRAIN

# %%
DATA AFLS.ADTRAIN;
   SET AFLS.ATRAIN;
   FILE PRINT;
   SET AFLS.ATRAIN (KEEP= adult_id workclass occupation native_country);
   IF _N_ = 1 AND workclass eq '?' THEN DELETE ;
   IF occupation eq '?' THEN DELETE ;
   IF native_country eq '?' THEN DELETE ;
RUN;

   TITLE "NEW DATASET AFLS.ADTRAIN without missing values in character variables";
PROC PRINT DATA=AFLS.ADTRAIN (OBS=10);
RUN;

   TITLE "No. Of OBSERVATIONS REDUCED IN NEW DATASET AFTER DELETION";
PROC CONTENTS DATA=AFLS.ADTRAIN VARNUM ;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# ##### There are no Errors in any Character Variables so no need of any Treatment for Errors in character variables.

# %% [markdown]
# #### YOU CAN SEE THAT AFTER REMOVING ALL THE OBSERVATIONS CONTAINING MISSING VALUES IN CHARACTER VARIABLES OUR NEW DATA SET AFLS.ADTRAIN BECAME SMALLAR WITH 30162 OBSERVATIONS WHICH WAS BERORE 32561 (AFLS.ATRAIN) SO, WE COULD REMOVE 2399 OBSERVATIONS APPROXIMATELY 7.37%
# Generally we avoid to remove the observations, but here as it was less than 10% and catagorical variable we cannot put mean or median there like numeric variables and  from '?' to replacing it with global constants like 'NA' or 'UNKNOWN' has no meaning so we decided to remove the observations from the data set and create a new dataset without missing values in character variables.

# %% [markdown]
# ###    b. Numeric Variables.

# %% [markdown]
# ##### For numeric variables we will first create a temperory dataset without the values of 99,999,9999,99999 & 999999 with the help of macro.
# And then we will find out the mean and median values for each variables. This mean or median values we will put in our variables with missing values depending on whether it is normally distributed or not. We saw that out of 6 we have missing values containing 99,999,9999,99999,999999 are only two variables capital_gain and hours_per_week so we will apply this on those two variables but first let's check after removing all the observations containing the missing values in character data how many missing values now remaining in both the variables.

# %% [markdown]
# ### Let's start with AFLS.ADTRAIN DATASET.

# %%
DATA AFLS.missingninetrain;
   SET AFLS.ADTRAIN (DROP = adult_id);
   ARRAY Nums[*] _numeric_;
   DO iii = 1 TO DIM (Nums);
   IF Nums[iii] = 99 THEN Nums[iii] = .;
   ELSE IF Nums[iii] = 999 THEN Nums[iii] = .;
   ELSE IF Nums[iii] = 9999 THEN Nums[iii] = .;
   ELSE IF Nums[iii] = 99999 THEN Nums[iii] =.;
   ELSE IF Nums[iii] = 999999 THEN Nums[iii] = .;
   END
   ;
   DROP iii;
RUN;

   TITLE"Checking Missing Values from the AFLS.ADTRAIN  and calculating Mean and Median";
PROC MEANS DATA =AFLS.missingninetrain n nmiss Mean Std Median ;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# #### Now you can see that it reduced for capital_gain from 159 to 148 and for hours_per_week 85 to 78.

# %% [markdown]
# ##### After removal of observations of missing values in variables workclass, occupation and native_country we can see that observations with missing values in capital_gain reduced from 159 to 148 and in hours_per_week reduced from 85 to 78, you can see now we  replaced 99,999,9999,99999 & 999999 to SAS missing value '.'

# %% [markdown]
# ##### Let's check capital_gain if it is normal we will add mean and if not normal we shall add median.

# %%
   TITLE 'Histogram for capital_gain';
PROC UNIVARIATE DATA = AFLS.missingninetrain NOPRINT;
   HISTOGRAM capital_gain / NORMAL;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# #### We can see that capital_gain histogram in the PROC UNIVARIATE procesure is not normal so we will add median in place of missing values.

# %% [markdown]
# ##### Let's check hours_per_week if it si normal we will add mean and if not normal we shall add median.

# %%
   TITLE 'Histogram for hours_per_week';
PROC UNIVARIATE DATA = AFLS.missingninetrain NOPRINT;
   HISTOGRAM hours_per_week / NORMAL;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# #### We can see that hours_per_week histogram in the PROC UNIVARIATE procesure is vary flat but normal so we will add mean in place of missing values.

# %%
PROC STDIZE DATA= AFLS.missingninetrain
   OUT = AFLS.ADJTRAIN
   METHOD = MEDIAN REPONLY;
   VAR capital_gain ;
RUN;
  
   TITLE "REPLACING SAS MISSING VALUES with Median ";
PROC MEANS DATA=AFLS.ADJTRAIN N NMISS MEAN MEDIAN STD MIN MAX ;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
PROC STDIZE DATA= AFLS.ADJTRAIN
   OUT = AFLS.ATRAIN
   METHOD = MEAN REPONLY;
   VAR hours_per_week ;
RUN;
  
   TITLE "REPLACING SAS MISSING VALUES with Median ";
PROC MEANS DATA=AFLS.ATRAIN N NMISS MEAN MEDIAN STD MIN MAX ;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
DATA AFLS.ATRAIN;
   SET AFLS.ATRAIN;
   adult_id = _N_;
RUN;

 TITLE "Random 10 observations showing missing value and new variable adult_id";
PROC PRINT DATA=AFLS.ATRAIN(FIRSTOBS=1561 OBS=1570) NOOBS;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# ## So in this step STEP-03 We treated missing values, some observations containing missing values in character varaiables those we removed and
#
# some observations containing missing values in numeric variable there we replaced those missing values with the mean or median.
#
# NOW NEXT STEP IS TO FIND THE OUTLIERS.

# %% [markdown]
# # STEP - 04  and STEP - 05 : Outliers Finding and Treating.
# ###    a. Character Variables.

# %% [markdown]
# ##### Character variables/categorical variables do not have outliers in general, if we create class and then one value is not of that class can be considered as outlier or Error but here in our case no character variable is having such characteristics, so we can say that there are no out liers in character variables in AFLS.ATRAIN.

# %% [markdown]
# ###    b. Numeric Variables.

# %% [markdown]
# #### OUTLIERS
# There are three methos for  finding outliers
# 1. Univariate method: This method looks for data points with extreme values on one variable.
# 2. Multivariate method: Here we look for unusual combinations on all the variables.
# 3. Minkowski error: This method reduces the contribution of potential outliers in the training process.
#
# We wil use Univariate method.
#
# Detection of Outliers
#
# If a value is higher than the 1.5 times of Interquartile Range (IQR) above the upper quartile (Q3), the value will be considered as mild-outlier. Similarly, if a value is lower than the 1.5 times of IQR below the lower quartile (Q1), the value will be considered as mild-outlier.
#
# If a value is higher than the 3 times of Interquartile Range (IQR) above the upper quartile (Q3), the value will be considered as extreme-outlier. Similarly, if a value is lower than the 3 times of IQR below the lower quartile (Q1), the value will be considered as extreme-outlier.

# %% [markdown]
# ##### We will use histograms to see normality & boxplot to find outliers.

# %% [markdown]
# ### Let's Start with AFLS.ATRAIN.

# %%
   TITLE 'Distribution of age';
PROC SGPLOT DATA=AFLS.ATRAIN;
   HISTOGRAM age;
   DENSITY age;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
   TITLE "Box plot of age";
PROC SGPLOT DATA=AFLS.ATRAIN;
   VBOX age;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
PROC MEANS DATA = AFLS.ATRAIN NOPRINT ; 
   VAR age;
   OUTPUT OUT = TMP (DROP = _TYPE_ _FREQ_)
          Q1 = 
          Q3 = 
          QRange = /AUTONAME;
RUN;

   TITLE "Q1,Q3 and QRange for age";
PROC PRINT DATA = TMP;
RUN;

   TITLE "Outliers Based on Interquartile Range";
DATA _null_;
   FILE print;
   SET AFLS.ATRAIN(KEEP = adult_id age);
   IF _n_ = 1 THEN SET Tmp;
   IF age lt age_Q1 - 1.5*age_QRange AND NOT MISSING (age)
   or age gt age_Q3 + 1.5*age_QRange THEN 
   PUT "Possible Outlier for age " adult_id "Value of age = " age;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# ##### Here logically we can understand that as  Q1=28,Q3=47 & IQR=19, Q3+1.5IQR= 76 yers and age above 76 cannot earn except from investments and pension in general, so if we are removing those outlier evenif they are not extreame as not outside Q3+3IQR still we shall remove them.

# %% [markdown]
# ##### Removing outliers from age.

# %%
PROC MEANS DATA = AFLS.ATRAIN NOPRINT ; 
   VAR age;
   OUTPUT OUT = TMP (DROP = _TYPE_ _FREQ_)
          Q1 = 
          Q3 = 
          QRange = /AUTONAME;
RUN;
   
   TITLE "AFLS.ATRAIN after removing outliers for age";
DATA AFLS.ATRAIN_Outage;
   SET AFLS.ATRAIN;
   FILE print;
   SET AFLS.ATRAIN (KEEP = adult_id age);
   IF _n_ = 1 THEN SET Tmp;
   IF age lt age_Q1 - 1.5*age_QRange AND NOT MISSING (age)
   or age gt age_Q3 + 1.5*age_QRange THEN DELETE ;
   DROP age_Q1 age_Q3 age_QRange;
RUN;

PROC CONTENTS DATA=AFLS.ATRAIN_Outage VARNUM ;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# ##### You can see we removed outliers for age from the dataset and new dataset AFLS.ATRAIN_Outage is having observations 29993, before there were 30162 observations we removed 169 observations. Let's also confirm graphically by box plot.

# %%
   TITLE "Box plot of age after Treatment";
PROC SGPLOT DATA=AFLS.ATRAIN_Outage;
   VBOX age;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# ### We can see above in box plot that now there are no outliers in the variable age.

# %%
   TITLE 'Distribution of fnlwgt';
PROC SGPLOT DATA=AFLS.ATRAIN_Outage;
   HISTOGRAM fnlwgt;
   DENSITY fnlwgt;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
   TITLE "Box plot of fnlwgt";
PROC SGPLOT DATA=AFLS.ATRAIN_Outage;
   VBOX fnlwgt;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
PROC MEANS DATA = AFLS.ATRAIN_Outage NOPRINT ; 
   VAR fnlwgt;
   OUTPUT OUT = TMP (DROP = _TYPE_ _FREQ_)
          Q1 = 
          Q3 = 
          QRange = /AUTONAME;
RUN;

   TITLE "Q1,Q3 and QRange for fnlwgt";
PROC PRINT DATA = TMP;
RUN;

   TITLE "Outliers Based on Interquartile Range";
DATA _null_;
   FILE print;
   SET AFLS.ATRAIN_Outage(KEEP = adult_id fnlwgt);
   IF _n_ = 1 THEN SET Tmp;
   IF fnlwgt lt fnlwgt_Q1 - 1.5*fnlwgt_QRange AND NOT MISSING (fnlwgt)
   or fnlwgt gt fnlwgt_Q3 + 1.5*fnlwgt_QRange THEN 
   PUT "Possible Outlier for fnlwgt " adult_id "Value of fnlwgt = " fnlwgt;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# ##### Let's check for extreame outliers for fnlwgt.

# %%
PROC MEANS DATA = AFLS.ATRAIN_Outage NOPRINT ; 
   VAR fnlwgt;
   OUTPUT OUT = TMP (DROP = _TYPE_ _FREQ_)
          Q1 = 
          Q3 = 
          QRange = /AUTONAME;
RUN;

   TITLE "Q1,Q3 and QRange for fnlwgt";
PROC PRINT DATA = TMP;
RUN;

   TITLE "Outliers Based on Interquartile Range";
DATA _null_;
   FILE print;
   SET AFLS.ATRAIN_Outage(KEEP = adult_id fnlwgt);
   IF _n_ = 1 THEN SET Tmp;
   IF fnlwgt lt fnlwgt_Q1 - 3*fnlwgt_QRange AND NOT MISSING (fnlwgt)
   or fnlwgt gt fnlwgt_Q3 + 3*fnlwgt_QRange THEN 
   PUT "Possible Outlier for fnlwgt " adult_id "Value of fnlwgt = " fnlwgt;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# ##### We shall avoid removing observations if it does not serve our objective, here we can remove above outliers from the dataset,
# but, let's understand this variable final weight=fnlwgt. It is the representation of the US population in this
# data set and that was calculated with three controls and also multiplied those by 6 so that by the end we come
# back to all the value.
# Following is the details;
# Description of fnlwgt (final weight)
#
# The weights on the CPS files are controlled to independent estimates of the
# civilian noninstitutional population of the US.  These are prepared monthly
# for us by Population Division here at the Census Bureau.  We use 3 sets of controls.
# These are:
# 1.  A single cell estimate of the population 16+ for each state.
# 2.  Controls for Hispanic Origin by age and sex.
# 3.  Controls by Race, age and sex.
#
# We use all three sets of controls in our weighting program and "rake" through them 6 times so that by the
# end we come back to all the controls we used.
# The term estimate refers to population totals derived from CPS by creating
# "weighted tallies" of any specified socio-economic characteristics of the population.
# People with similar demographic characteristics should have
# similar weights.  There is one important caveat to remember
# about this statement.  That is that since the CPS sample is
# actually a collection of 51 state samples, each with its own
# probability of selection, the statement only applies within state.
#
# ### Above details explains that if we devide fnlwgt by 3x6=18 times we will get the representation of the US population.
# for example if fnlwgt =90000 means 90000/18=5000, that observation is representing 5000 US residents with age more than 16 years. So, if we remove the extreame values as outliers, actually we are removing the representation of US population.
#
# ## So, for this variable "fnlwgt"  We prefer not to remove any outliers evenif there are some extreame outliers.

# %%
   TITLE 'Distribution of education_num';
PROC SGPLOT DATA=AFLS.ATRAIN_Outage;
   HISTOGRAM education_num;
   DENSITY education_num;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
   TITLE "Box plot of education_num";
PROC SGPLOT DATA=AFLS.ATRAIN_Outage;
   VBOX education_num;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# ##### Here we can see from boxplot that ther are 2 outliers (there may be more on the same spot) let's find it by IQR method.

# %%
PROC MEANS DATA = AFLS.ATRAIN_Outage NOPRINT ; 
   VAR education_num;
   OUTPUT OUT = TMP (DROP = _TYPE_ _FREQ_)
          Q1 = 
          Q3 = 
          QRange = /AUTONAME;
RUN;

   TITLE "Q1,Q3 and QRange for education_num";
PROC PRINT DATA = TMP;
RUN;

   TITLE "Outliers Based on Interquartile Range";
DATA _null_;
   FILE print;
   SET AFLS.ATRAIN_Outage(KEEP = adult_id education_num);
   IF _n_ = 1 THEN SET Tmp;
   IF education_num lt education_num_Q1 - 1.5*education_num_QRange AND NOT MISSING (education_num)
   or education_num gt education_num_Q3 + 1.5*education_num_QRange THEN 
   PUT "Possible Outlier for education_num " adult_id "Value of edufation_num = " education_num;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
PROC MEANS DATA = AFLS.ATRAIN_Outage NOPRINT ; 
   VAR education_num;
   OUTPUT OUT = TMP (DROP = _TYPE_ _FREQ_)
          Q1 = 
          Q3 = 
          QRange = /AUTONAME;
RUN;

   TITLE "Q1,Q3 and QRange for education_num";
PROC PRINT DATA = TMP;
RUN;

   TITLE "Outliers Based on Interquartile Range";
DATA _null_;
   FILE print;
   SET AFLS.ATRAIN_Outage(KEEP = adult_id education_num);
   IF _n_ = 1 THEN SET Tmp;
   IF education_num lt education_num_Q1 - 3*education_num_QRange AND NOT MISSING (education_num)
   or education_num gt education_num_Q3 + 3*education_num_QRange THEN 
   PUT "Possible Extreame Outlier for education_num " adult_id "Value of edufation_num = " education_num;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# #### We can see that there are no extreame values for education_num, but mild outliers are 1 and 2 yrs of education. we will put the minimum value acceptable as non outlier that is 9-1.5x4=9-6=3.

# %%
DATA AFLS.ATRAIN_Outedu;
   SET AFLS.ATRAIN_Outage;
   IF education_num = 1 THEN education_num = 3;
RUN;

   TITLE "Statistics for education_num changes";
PROC MEANS DATA=AFLS.ATRAIN_Outedu N NMISS MEAN MEDIAN STD MIN MAX;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# ##### You can see we replace education_num = 1 with education_num=3 so min=2 now let's again do the same process to replace education_num=2 to education_num = 3 so, our outliers will be adjusted to the nearest clusters and we will not loose any data. our new minimum will be 3.

# %%
DATA AFLS.ATRAIN_Outedu;
   SET AFLS.ATRAIN_Outedu;
   IF education_num = 2 THEN education_num = 3;
RUN;

   TITLE "STATISTICS FOR education_num";
PROC MEANS DATA=AFLS.ATRAIN_Outedu N NMISS MEAN MEDIAN STD MIN MAX;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# #### Let's check boxplot to see whether outliers treated or not.

# %%
   TITLE "Box plot of education_num after treatment";
PROC SGPLOT DATA=AFLS.ATRAIN_Outedu;
   VBOX education_num;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# ##### We can see that now there are no outliers in the education_num, which also identified by PROC MEANS procedure where we got minimum value equals to 3. and here through box plot also we confirmed.

# %%
   TITLE 'Distribution of capital_gain';
PROC SGPLOT DATA=AFLS.ATRAIN_Outedu;
   HISTOGRAM capital_gain;
   DENSITY capital_gain;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
   TITLE "Box plot of capital_gain";
PROC SGPLOT DATA=AFLS.ATRAIN_Outedu;
   VBOX capital_gain;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# ##### Here we can see that there is no box meaning that Q1=Q2=Q3=0 so its useless to find outliers and remove them or replace them with the mean or median. Logically those who have capital_loss will never have capital_gain so the value will be zero, more over in general those who get capital_gain always fewer compared to those who are either having capital_loss or no loss or profit. Here we already treated missing values replacing with median. but treating outliers will make everything zero, so we are living this variable as it is to avoid any further loss of data.

# %%
   TITLE 'Distribution of capital_loss';
PROC SGPLOT DATA=AFLS.ATRAIN_Outedu;
   HISTOGRAM capital_loss;
   DENSITY capital_loss;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
   TITLE "Box plot of capital_loss";
PROC SGPLOT DATA=AFLS.ATRAIN_Outedu;
   VBOX capital_loss;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# ##### Similarly, like capital_gain, here we can see that there is no box meaning that Q1=Q2=Q3=0 so its useless to find outliers and remove them or replace them with the mean or median. Logically those who have capital_gain will never have capital_loss so the value will be zero, more over in general those who get capital_loss always fewer compared to those who are either having no loss or profit. Here we already treated missing values replacing with median. but treating outliers will make everything zero, so we are living this variable as it is to avoid any further loss of data.

# %%
   TITLE 'Distribution of hours_per_week';
PROC SGPLOT DATA=AFLS.ATRAIN_Outedu;
   HISTOGRAM hours_per_week;
   DENSITY hours_per_week;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
   TITLE "Box plot of hours_per_week";
PROC SGPLOT DATA=AFLS.ATRAIN_Outedu;
   VBOX hours_per_week;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# ##### Let's find outliers and extreame outliers, to make sense we will remove extream outliers and we will replace mild outliers with the nearest cluster means if upper mild outlier we will replace with maximum and if lower mild outlier we will replace with minimum.

# %% [markdown]
# ##### Let's first see extreame outliers and remove them.

# %%
PROC MEANS DATA = AFLS.ATRAIN_Outedu NOPRINT ; 
   VAR hours_per_week;
   OUTPUT OUT = TMP (DROP = _TYPE_ _FREQ_)
          Q1 = 
          Q3 = 
          QRange = /AUTONAME;
RUN;

   TITLE "Q1,Q3 and QRange for hours_per_week";
PROC PRINT DATA = TMP;
RUN;

   TITLE "Outliers Based on Interquartile Range";
DATA _null_;
   FILE print;
   SET AFLS.ATRAIN_Outedu(KEEP = adult_id hours_per_week);
   IF _n_ = 1 THEN SET Tmp;
   IF hours_per_week lt hours_per_week_Q1 - 3*hours_per_week_QRange AND NOT MISSING (hours_per_week)
   or hours_per_week gt hours_per_week_Q3 + 3*hours_per_week_QRange THEN 
   PUT "Possible Extreame Outlier for hours_per_week " adult_id "Value of hours_per_week = " hours_per_week;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# ##### The variable hours_per_week closely connected with the workclass variable, where never worked people may have hours_per_week equals zero, more over some emergency duty kind of nature of workclass may increase working hours up to 60 or more, so the idea is here instead of blancketly removing the outlier we shall create a range from 20 hrs to 60 hrs and those higher than 60 hrs shall be kept as 60 hrs and those lower than 20 hrs shall be kept as 20 hrs, this will adjust the sum of hours_per_week and the data will have less spread so easy to analyse.
# So, basically we are mapping the variable hours_per_week, instead of from 0 to 98 we are converting it to 20 to 60.

# %%
DATA AFLS.ATRAIN_Outhpw;
   SET AFLS.ATRAIN_Outedu;
   IF hours_per_week > 60 THEN hours_per_week = 60;
RUN;

   TITLE "Statistics of hours_per_week changes";
PROC MEANS DATA=AFLS.ATRAIN_Outhpw N NMISS MEAN MEDIAN STD MIN MAX;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# ##### You can see we changed upper limit to 60 as maximum for hours_per_week = 60, now let's change lower limit to 20.

# %%
DATA AFLS.ATRAIN;
   SET AFLS.ATRAIN_Outhpw;
   IF hours_per_week < 20 THEN hours_per_week = 20;
RUN;

   TITLE "STATISTICS FOR hours_per_week changes";
PROC MEANS DATA=AFLS.ATRAIN N NMISS MEAN MEDIAN STD MIN MAX;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# ##### Now, you can see we replace lower limit to 20.

# %% [markdown]
# #### Here, we perform all the tasks required for STEP-04 and STEP-05 on the data set AFLS.ATRAIN.

# %% [markdown]
# # STEP - 06  and STEP - 07: Duplicate Observations Finding  and Removing from the Data set.

# %% [markdown]
# ### Now let's see if there are any duplicate observations in the data sets ALFS.ATRAIN, if there are duplicate observations we shall remove them.

# %%
   TITLE "Statistics for AFLS.ATRAIN DATA SET";
PROC MEANS DATA=AFLS.ATRAIN N NMISS MEAN MEDIAN STD MIN MAX ;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# ##### We can see currently we have 29993 observations in AFLS.ATRAIN Dataset.

# %%
PROC SQL NOPRINT;
   CREATE TABLE AFLS.ADULTTRAIN AS SELECT DISTINCT * FROM AFLS.ATRAIN;
QUIT;

PROC SORT DATA=AFLS.ADULTTRAIN;
BY adult_id;
RUN;

   TITLE "First 5 observations for AFLS.ADULTTRAIN DATA SET";
PROC PRINT DATA=AFLS.ADULTTRAIN (OBS=5);
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
   TITLE "Statistics for AFLS.ADULTTRAIN DATA SET";
PROC MEANS DATA=AFLS.ADULTTRAIN N NMISS MEAN MEDIAN STD MIN MAX ;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# ##### As per the document there shall be 6 duplications total in 32561 + 16281 = 48842 observatrions, but after removing & treating missing values and outliers we saw that now there are no duplicate observations so still the no. of observations are same as before the process of removal of duplication that is 29993.

# %% [markdown]
# # STEP - 08 : Convert Annual_Income Variable int '0' and '1' and from catagorical to numeric variable.

# %% [markdown]
# ##### For AFLS.ATRAIN DATA SET.

# %%
DATA AFLS.ATRAIN;
   SET AFLS.ADULTTRAIN;
   IF annual_incomegt50k = '<=50K' THEN annual_incomegt50k = '0';
   IF annual_incomegt50k = '>50K' THEN annual_incomegt50k = '1';
RUN;

   TITLE "First 10 observations for AFLS.ATRAIN DATA SET";
PROC PRINT DATA=AFLS.ATRAIN (OBS=10);
RUN;
  
   TITLE "VARIABLE DESCRIPTION FOR AFLS.ATRAIN DATA SET";
PROC CONTENTS DATA=AFLS.ATRAIN VARNUM;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# ##### You can see that we changed the catagorical variable annual_incomegt50k to '0' & '1' for '<=50K' and '>50K' respectively, but still we didn't transform it to numeric variable as we can see in PROC CONTENTS output it shows TYPE - CHAR. so let's change it to numeric variable.

# %%
DATA AFLS.ATRAIN;
   SET AFLS.ATRAIN;
   annual_income = INPUT(annual_incomegt50k,8.);
   DROP annual_incomegt50k;
RUN;

   TITLE "FIRST 10 OBSERVATIONS FOR AFLS.ATRAIN DATA SET";
PROC PRINT DATA=AFLS.ATRAIN (OBS=10);
RUN;

   TITLE "VARIABLE DESCRIPTION FOR AFLS.ATRAIN DATA SET";
PROC CONTENTS DATA=AFLS.ATRAIN VARNUM;
RUN;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# ##### We can see that annual_income variable type became Num now.

# %% [markdown]
# # Here we have completed all the 8 steps and now our data set AFLS.ATRAIN  and it is pre-processed and cleaned.
# ## Now we can use this  data set for further predctive analysis and model building.
#
# ###  @@@@ THANK YOU @@@@
